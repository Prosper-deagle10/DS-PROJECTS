# %% [markdown]
# # # About Dataset¶
# # This is dummy data, that I have generated by using the 'NumPy' Library of Python. This data shows how much a user spends time on their devices using Social Media.​I generated this data to train an AI model for myself for practice purposes only.​The description for each column is as follows:​
#
# # age: The age of the user.
# # gender: The gender identity of the user (Male, Female).
# # demographics: The type of area the user resides in (Urban, Suburban, Rural).
# # interests: The user's primary area of interest or hobby.
# # device_type: The type of device used by the user (Mobile).
# # location:The LGA of residence for the user.
# # platform: The social media platform where the user spends time.
# # profession: The user's occupation or professional status.
# # income: The yearly income of the user.

# %%
age = np.random.randint(15,30,(30,1))
data['Age'] = age
data = pd.DataFrame(age)

# Adding a random 'Interest' column
interest = np.random.choice(['business', 'entertainment', 'content', 'influence', 'others'], size=len(data))
data['Interest'] = interest

# Adding a random 'Device_type' column
device_type = np.random.choice(['iPhone', 'SmartPhone', 'Laptop'], size=len(data))
data['Device_type'] = device_type

# Adding a random 'Time_spent' column
time = np.random.randint(1,9,(30,1))
data['Time_spent (hr)'] = time

# Adding a random 'Location' column
location = np.random.choice(['Tai', 'Khana', 'Eleme', 'Gokana'], size=len(data))
data['Location'] = location

# Adding a random 'Platform' column
platform = np.random.choice(['Facebook', 'Instagram', 'WhatsApp', 'All'], size=len(data))
data['Platform'] = platform

# Adding a random 'Profession' column
profession = np.random.choice(['Student', 'Digital_Marketer', 'Others'], size=len(data))
data['Profession'] = profession

# Adding a random 'Demographics' column
demographics = np.random.choice(['Urban', 'Suburban', 'Rural'], size=len(data))
data['Demographics'] = demographics

# Adding a random 'Income' column
income = np.random.randint(10000,60000, size=len(data))
data['Income (#)'] = income

# Adding a random 'Gender' column
gender = np.random.choice(['Male', 'Female'], size=len(data))
data['Gender'] = gender


# Display the resulting DataFrame
print(data)
# Out:
#      0       Interest Device_type  Time_spent (hr) Location   Platform  \
# 0   23         others  SmartPhone                2    Eleme   Facebook
# 1   25         others      iPhone                7    Khana   Facebook
# 2   17       business      Laptop                2      Tai   Facebook
# 3   23       business  SmartPhone                3    Eleme  Instagram
# 4   28        content      Laptop                1      Tai   Facebook
# 5   24         others      Laptop                2    Eleme  Instagram
# 6   17        content      iPhone                7   Gokana   WhatsApp
# 7   18         others  SmartPhone                2   Gokana   Facebook
# 8   18         others      Laptop                3    Eleme   Facebook
# 9   25      influence  SmartPhone                5    Eleme        All
# 10  21        content  SmartPhone                1    Khana        All
# 11  25  entertainment  SmartPhone                3    Eleme   WhatsApp
# ...

# %%
# Rename the unnamed column to 'NewName'
data.rename(columns={data.columns[0]: 'Age'}, inplace=True)

# Display the resulting DataFrame
print(data)
# Out:
#     Age       Interest Device_type  Time_spent (hr) Location   Platform  \
# 0    23         others  SmartPhone                2    Eleme   Facebook
# 1    25         others      iPhone                7    Khana   Facebook
# 2    17       business      Laptop                2      Tai   Facebook
# 3    23       business  SmartPhone                3    Eleme  Instagram
# 4    28        content      Laptop                1      Tai   Facebook
# 5    24         others      Laptop                2    Eleme  Instagram
# 6    17        content      iPhone                7   Gokana   WhatsApp
# 7    18         others  SmartPhone                2   Gokana   Facebook
# 8    18         others      Laptop                3    Eleme   Facebook
# 9    25      influence  SmartPhone                5    Eleme        All
# 10   21        content  SmartPhone                1    Khana        All
# 11   25  entertainment  SmartPhone                3    Eleme   WhatsApp
# ...

# %% [markdown]
# # Loading the Data

# %%
# Out:
#     Age       Interest Device_type  Time_spent (hr) Location   Platform  \
# 0    23         others  SmartPhone                2    Eleme   Facebook
# 1    25         others      iPhone                7    Khana   Facebook
# 2    17       business      Laptop                2      Tai   Facebook
# 3    23       business  SmartPhone                3    Eleme  Instagram
# 4    28        content      Laptop                1      Tai   Facebook
# 5    24         others      Laptop                2    Eleme  Instagram
# 6    17        content      iPhone                7   Gokana   WhatsApp
# 7    18         others  SmartPhone                2   Gokana   Facebook
# 8    18         others      Laptop                3    Eleme   Facebook
# 9    25      influence  SmartPhone                5    Eleme        All
# 10   21        content  SmartPhone                1    Khana        All
# 11   25  entertainment  SmartPhone                3    Eleme   WhatsApp
# ...

# %% [markdown]
# ## Data Preprocessing steps¶
# ## Checking the data shape
# ## Checking the null values
# ## Some Stastical information
# ## information about data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              30 non-null     int32
#  1   Interest         30 non-null     object
#  2   Device_type      30 non-null     object
#  3   Time_spent (hr)  30 non-null     int32
#  4   Location         30 non-null     object
#  5   Platform         30 non-null     object
#  6   Profession       30 non-null     object
#  7   Demographics     30 non-null     object
#  8   Income (#)       30 non-null     int32
#  9   Gender           30 non-null     object
# dtypes: int32(3), object(7)
# memory usage: 2.1+ KB

# %%
data.describe().style.background_gradient(cmap='RdGy_r')
# Out:
# <style type="text/css">
# #T_c1af1_row0_col0, #T_c1af1_row0_col1, #T_c1af1_row7_col2 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_c1af1_row0_col2, #T_c1af1_row2_col0, #T_c1af1_row3_col1 {
#   background-color: #1a1a1a;
#   color: #f1f1f1;
# }
# #T_c1af1_row1_col0 {
#   background-color: #f4a683;
#   color: #000000;
# }
# #T_c1af1_row1_col1 {
#   background-color: #4c4c4c;
#   color: #f1f1f1;
# }
# #T_c1af1_row1_col2 {
#   background-color: #fffaf7;
#   color: #000000;
# }
# #T_c1af1_row2_col1 {
#   background-color: #2e2e2e;
#   color: #f1f1f1;
# }
# #T_c1af1_row2_col2 {
#   background-color: #9f9f9f;
#   color: #f1f1f1;
# }
# #T_c1af1_row3_col0 {
#   background-color: #e7e7e7;
#   color: #000000;
# }
# #T_c1af1_row3_col2 {
#   background-color: #777777;
#   color: #f1f1f1;
# }
# #T_c1af1_row4_col0 {
#   background-color: #fef2ea;
#   color: #000000;
# }
# #T_c1af1_row4_col1 {
#   background-color: #2a2a2a;
#   color: #f1f1f1;
# }
# #T_c1af1_row4_col2 {
# ...

# %% [markdown]
# # Explore Data Analysis Process¶

# %% [markdown]
# ## Questions Asked from the Data. I ask some questions to find some intresting information about the data

# %% [markdown]
# ### Visualize the age distribution using a distplot.
# ### Create a pie chart to understand the gender percentage in the data.
# ### Visualize the unique plots in different locations.
# ### Visualize how many times students use different social media platforms in different locations.
# ### Create a data frame to show how much time each profession spends on different social media platforms on average.
# ### Create a data frame for demographics, platforms, and professions.

# %%
# Visualize the age distribution
plt.figure(figsize=(8,5))
sns.distplot(data['Age'],hist=True)
plt.title("Age Distribution plot")
plt.xlabel('Age')
plt.ylabel("Density")
plt.show()

# %%
# Let's Visualize the Gender Percentage in the data
data['Gender'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',figsize=(8,6), explode=[0,0.1], labels=['Male', 'Female'],\
      colors=['#780000','#e7c6ff'], autopct='%1.2f%%', shadow=True)
plt.title("Visualize the Gender percentage in the data")
plt.show()

# %%
# Let;s find the How many location in the data
data['Location'].value_counts().sort_values(ascending=True)\
.plot(kind='bar',figsize=(8,6),color=['#457b9d','#ef233c','#06d6a0'])
plt.title("Find how may location in the data")
plt.xlabel('Locations')
plt.ylabel("Count of the values")
plt.show()

# %%
# Let's find some intresting question
'''Let's find out how many total student visit the social media platform
in differnt locations
'''
student_data=data[data['Profession']=='Student']
location_platform_data_frame=pd.DataFrame(student_data.groupby('Location',)['Platform'].value_counts().sort_values(ascending=False).unstack())
# Reshaping the DataFrame for seaborn barplot
platform_counts = location_platform_data_frame.reset_index().melt(id_vars='Location', var_name='Platform', value_name='count')
# Plotting with seaborn
plt.figure(figsize=(8, 6))
sns.barplot(data=platform_counts, x='Location', y='count', hue='Platform', palette='YlGn_r')
# Adding labels and title
plt.xlabel('Location')
plt.ylabel('Number of Students')
plt.title('Platform Usage by Students per Location')

# Display the plot
plt.legend(title='Platform')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
'''
Let's find the average time for the all profession employess 
spends on the each social media platfom and 
'''
profession_platform=pd.DataFrame(data.groupby('Profession')['Platform'].value_counts().sort_values(ascending=False).unstack())
profession_time=pd.DataFrame(data.groupby('Profession')['Time_spent (hr)'].mean())
all_information=pd.merge(profession_platform,profession_time,on='Profession')
all_information.style.background_gradient(cmap='ocean')
# Out:
# <style type="text/css">
# #T_23f2d_row0_col0, #T_23f2d_row0_col4, #T_23f2d_row1_col2, #T_23f2d_row2_col1, #T_23f2d_row2_col2, #T_23f2d_row2_col3 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_23f2d_row0_col1, #T_23f2d_row0_col3 {
#   background-color: #004080;
#   color: #f1f1f1;
# }
# #T_23f2d_row0_col2, #T_23f2d_row1_col1, #T_23f2d_row1_col3, #T_23f2d_row1_col4, #T_23f2d_row2_col0 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_23f2d_row1_col0 {
#   background-color: #000055;
#   color: #f1f1f1;
# }
# #T_23f2d_row2_col4 {
#   background-color: #004583;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_23f2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23f2d_level0_col0" class="col_heading level0 col0" >All</th>
#       <th id="T_23f2d_level0_col1" class="col_heading level0 col1" >Facebook</th>
#       <th id="T_23f2d_level0_col2" class="col_heading level0 col2" >Instagram</th>
# ...

# %%
'''Create a chart to understanding the how many people mostly
using the social media with different demographics we do groupby function and then 
we do sort the values
'''
grouping_data=pd.DataFrame(data.groupby(['Platform','Demographics'])['Profession'].value_counts().sort_values().unstack())
grouping_data.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_f818b_row0_col0, #T_f818b_row0_col1, #T_f818b_row1_col0, #T_f818b_row1_col1, #T_f818b_row2_col0, #T_f818b_row2_col1, #T_f818b_row3_col0, #T_f818b_row3_col1, #T_f818b_row4_col0, #T_f818b_row5_col0, #T_f818b_row5_col2, #T_f818b_row6_col0, #T_f818b_row6_col2, #T_f818b_row7_col0, #T_f818b_row8_col0, #T_f818b_row8_col1, #T_f818b_row9_col0, #T_f818b_row9_col2, #T_f818b_row10_col0, #T_f818b_row11_col0, #T_f818b_row11_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f818b_row0_col2, #T_f818b_row2_col2 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_f818b_row1_col2, #T_f818b_row4_col1, #T_f818b_row5_col1, #T_f818b_row10_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f818b_row3_col2, #T_f818b_row4_col2, #T_f818b_row6_col1, #T_f818b_row7_col1, #T_f818b_row7_col2, #T_f818b_row8_col2, #T_f818b_row9_col1, #T_f818b_row10_col2, #T_f818b_row11_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# ...

# %% [markdown]
# ##### Based on the data, we can make the following observations:¶
# ### The age distribution shows that most of the people fall in the age range of 15 to 29.
# ### Looking at the gender category, we can see that males dominate the data, followed by female genders.
# ### In terms of unique values, Eleme has the highest values, followed by the Khana and the Gokana.
# ### When analyzing the social media behavior of students in different locations, we observed that in all LGA, the most used platforms are All of the social media.
# ### We also observed that students spend more time on social media compared to other professions.

# %%
''' Let's find the source of income of the different gender
using the pie chart 
'''
data.groupby('Gender')['Income (#)'].sum().sort_values(ascending=False).plot(kind='pie',figsize=(8,6), explode=[0,0.1],
    labels=['Male','Female'],
    colors=['#3a5a40','#d90429'],
    autopct='%1.2f%%',
    shadow=True)
plt.title("Find the income percentage in differnt gender")
plt.show()

# %%
'''Find out Which age pepole most used  social media platforms
in the data, we create a bar chart to understand the information clearly
'''
age_platform=data.groupby('Age')['Platform'].value_counts().sort_values(ascending=False).unstack()
fig=px.bar(age_platform,x=age_platform.index,y=age_platform.columns,title='Age based on differnt social media platform',color_discrete_sequence=['#90a955','#fca311','#d62828', '#80c958'])
fig.update_layout(legend_bgcolor='#e63946',plot_bgcolor='#f5cac3')
fig.show()
pyo.iplot(fig)

# %%
'''
We creat the barplot to understand the different intrests on the 
differnet social media platfoms and we visualize with plotly libaries

'''
interest_platform=data.groupby('Interest')['Platform'].value_counts().sort_values(ascending=False).unstack()
fig=px.histogram(interest_platform,x=interest_platform.index,y=interest_platform.columns,barmode='group',title=f'Platform preferce in intrest wise')
fig.update_layout(paper_bgcolor="#124559")
fig.show()
pyo.iplot(fig)

# %%
'''
Find the top 20 income with time spent in differnt social media platforms 
using the scatter plots
'''
plt.figure(figsize=(12,7))
for platform in data['Platform'].unique():
    sns.barplot(x='Income (#)',y='Time_spent (hr)',data=data[data['Platform']==platform].head(20),label=platform,palette='RdBu')
plt.title("Income vs Time Spent on Different Platforms ")
plt.xlabel('Income')
plt.ylabel('Time_spent (#)')
plt.tight_layout()
plt.legend(title='Platform')
plt.xticks(rotation=90)
plt.show()

# %%
# Create a bar chart to understand the time spent on differnt location in differnet platforms
time_spent_platform=['Platform','Location']
for time_platform_location in time_spent_platform:
    time_spent_vs_platform_location=pd.DataFrame(data.groupby(time_platform_location)['Time_spent (hr)'].mean().sort_values(ascending=False))
    fig=px.bar(time_spent_vs_platform_location,color=time_spent_vs_platform_location.index,color_discrete_sequence=px.colors.qualitative.D3,
              title='Time_spent Vs location in differnt platforms')
    fig.update_layout(plot_bgcolor='#e5e5e5')
    fig.show()
    pyo.iplot(fig)
